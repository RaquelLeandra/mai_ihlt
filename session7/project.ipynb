# %%
from scipy.stats import pearsonr
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import WhitespaceTokenizer
from nltk.metrics import jaccard_distance
import csv

# %% [markdown]
# ## Statement
# - Use data set and description of task Semantic Textual Similarity in SemEval 2012.
# - Implement some approaches to detect paraphrase using sentence similarity metrics.
#     + Explore some lexical dimensions.
#     + Explore the syntactic dimension alone.
#     + Explore the combination of both previous.
# - Add new components at your choice (optional).
# - Compare and comment the results achieved by these approaches among them and among the official results.
# - Send files to raco in IHLT STS Project before the oral presentation:
#     + Jupyter notebook: sts-[Student1]-[Student2].ipynb
#     + Slides: sts-[Student1]-[Student2].pdf

# %%
train_path = 'data/train/STS.input.MSRpar.txt'
train_gs_path = 'data/train/STS.gs.MSRpar.txt'
test_path = 'data/test-gold/STS.input.MSRpar.txt'
test_gs_path = 'data/test-gold/STS.gs.MSRpar.txt'
train_df = pd.read_csv(train_path, sep='\t', lineterminator='\n', names=['sentence0','sentence1'], header=None, quoting=csv.QUOTE_NONE)
train_gs = pd.read_csv(train_gs_path, sep='\t', lineterminator='\n', names=['labels'], header=None)
print(train_df.shape, train_gs.shape)
# Out:
# (750, 2) (750, 1)

# %%
train_df
# Out:
#                                              sentence0  \
# 0    But other sources close to the sale said Viven...
# 1    Micron has declared its first quarterly profit...
# 2    The fines are part of failed Republican effort...
# 3    The American Anglican Council, which represent...
# 4    The tech-loaded Nasdaq composite rose 20.96 po...
# 5    Amgen shares gained 93 cents, or 1.45 percent,...
# 6    U.S. prosecutors have arrested more than 130 i...
# 7    Chavez said investigators feel confident they'...
# 8    Authorities said the scientist properly quaran...
# 9    The support will come as a free software upgra...
# 10   The man accused of using fake grenades to comm...
# 11   Jim Williams, director of the US-VISIT project...
# 12   The hearing occurred a day after the Pentagon ...
# 13   The Episcopal Church ''is alienating itself fr...
# 14   Counties with population declines will be Verm...
# 15   Swartz, indicted in February, had argued that ...
# 16   The last time the survey was conducted, in 199...
# 17   Higher courts have ruled that the tablets brok...
# 18   They were at Raffles Hospital over the weekend...
# 19   When the bomb exploded at the Casa de España, ...
# 20   Plofsky said the commission won't investigate ...
# 21   In two weeks, he'll probably send out Peace Ru...
# 22   If convicted of the spying charges, he could f...
# 23   The technology-laced Nasdaq Composite Index wa...
# 24   Hilsenrath and Klarman each were indicted on t...
# 25   Entrenched interests are positioning themselve...
# 26   But church members and observers say they expe...
# 27   Squyres is principal investigator for the Athe...
# 28   The military said it had killed 12 rebels and ...
# 29   The new sensor -- dubbed CANARY for ''cellular...
# ..                                                 ...
# 720  A Merrill Lynch spokesman said "we are pleased...
# 721  Trans fats are created when hydrogen is added ...
# 722  Schroeder cancelled his Italian holiday after ...
# 723  Dell's OpenManage software includes Dell Updat...
# 724  He'll be swept over any minute or just die of ...
# 725  LURD's Ja'neh also called for an interim gover...
# 726  KEDO Spokesman, Roland Tricot said: "The execu...
# 727  But skeptics are concerned about the ease with...
# 728  Prof Sally Baldwin, 63, from York, fell into a...
# 729  It calls for the agency to plan an independent...
# 730  WorldCom's accounting problems came to light e...
# 731  Benchmark Treasury 10-year notes gained 17/32,...
# 732  Prosecutors did an about-face in May and asked...
# 733  Volume was moderate at 827.68 million shares, ...
# 734  Penn Traffic's stock closed at 36 cents per sh...
# 735  Hotly contested legislation that would change ...
# 736  However, other unions including the powerful C...
# 737  The family owns Cheetahs strip clubs here and ...
# 738  The new bill would have Medicare cover 95 perc...
# 739  Several thousand 3rd Infantry troops, includin...
# 740  The study also found that consumer goods adver...
# 741  Prairie dogs sold as exotic pets are believed ...
# 742  The defense cannot appeal Roush's ruling until...
# 743  Crohn's disease causes inflammation of the int...
# 744  The committee was appointed by Defense Secreta...
# 745  Authorities identified the tipster as Richard ...
# 746  Kiernan testified that Seifert had received a ...
# 747  Former Indiana Rep. Frank McCloskey, 64, died ...
# 748  Hospitals and the Red Cross appealed to blood ...
# 749  It is priced at $5,995 for an unlimited number...
#
#                                              sentence1
# 0    But other sources close to the sale said Viven...
# 1    Micron's numbers also marked the first quarter...
# 2    Perry said he backs the Senate's efforts, incl...
# 3    The American Anglican Council, which represent...
# 4    The technology-laced Nasdaq Composite Index <....
# 5    Shares of Allergan were up 14 cents at $78.40 ...
# 6    More than 130 people have been arrested and $1...
# 7    Albuquerque Mayor Martin Chavez said investiga...
# 8    The scientist also quarantined himself at home...
# 9    The upgrade will be available as a free downlo...
# 10   A Cuban architect was sentenced to 20 years in...
# 11   Jim Williams, director of the US-VISIT project...
# 12   The hearing came one day after the Pentagon fo...
# 13   In Nairobi, the provost of All Saints Cathedra...
# 14   Vermillion, Posey and Madison County populatio...
# 15   Swartz had sought to have the charges dismisse...
# 16   In 1995, the last survey, those numbers were e...
# 17   The federal courts have ruled that the monumen...
# 18   They underwent more tests over the weekend, an...
# 19   At the Casa de Espaa, customers were eating di...
# 20   The panel will not begin a formal investigatio...
# 21   Frankel said Peace Rules will run in the Preak...
# 22   The charges of espionage and aiding the enemy ...
# 23   The broader Standard & Poor's 500 Index <.SPX>...
# 24   Klarman was charged with 16 counts of wire fraud.
# 25   It may be dying because entrenched interests a...
# 26   But church members and observers say they anti...
# 27   Steve Squyres, a Cornell University scientist,...
# 28   The military said it had killed 16 rebels and ...
# 29   The team has named the sensor Canary, for cell...
# ..                                                 ...
# 720  "We are very pleased with the judge's decision...
# 721  Trans fats are created when vegetable oil has ...
# 722  Stefani's remarks further stoked tension after...
# 723  The update packages help "automate the managem...
# 724  From the top of the embankment, Moriarty thoug...
# 725  The rebels are also calling for the deployment...
# 726  "The executive board decided to refer this to ...
# 727  But skeptics are concerned about the ease at w...
# 728  Sally Baldwin, from York, was killed instantly...
# 729  The agency has yet to fully formulate a strate...
# 730  WorldCom's financial troubles came to light la...
# 731  The benchmark 10-year note was recently down 1...
# 732  They asked that the autopsy reports be unseale...
# 733  Volume came to 439.66 million shares, below 45...
# 734  Penn Traffic stock closed Wednesday at 36 cent...
# 735  Legislation that would change state takeover l...
# 736  The powerful CGT and other unions remained opp...
# 737  The searches were conducted simultaneously wit...
# 738  Above that, seniors would be responsible for 1...
# 739  A few thousand troops, most from the division'...
# 740  In the second quarter, consumer advertisers co...
# 741  Prairie dogs are believed to have become infec...
# 742  Defense lawyers cannot appeal the ruling until...
# 743  Symptoms include chronic diarrhoea, abdominal ...
# 744  The public hearing is the second for the panel...
# 745  Powell is serving time in a different case -- ...
# 746  Seifert, he testified, had a gunshot wound in ...
# 747  McCloskey died Sunday afternoon in his home af...
# 748  The Connecticut Hospital Association joined th...
# 749  It is priced at $5,995 or $195 on a per user l...
#
# [750 rows x 2 columns]

# %%
def lemmatize_text(text):
    lemmatizer = WordNetLemmatizer()
    w_tokenizer = WhitespaceTokenizer()
    return [lemmatizer.lemmatize(w) for w in w_tokenizer.tokenize(text)]

# %%
def preprocessing(data):
    # todo: better handling of na
    data = data.fillna('')
    for column in data.columns:
        print(column)
        # remove the digits and puntuation
        data[column] = data[column].str.replace('\d+', '')
        # convert to lowercase
        data[column] = data[column].str.replace('\W+', ' ')
        # replace continuous white spaces by a single one
        data[column] = data[column].str.replace('\s+', ' ')
        # words to lower
        data[column] =data[column].str.lower()
        # lematize
        data[column] = data[column].apply(lemmatize_text)
    return data

# %%
train_df = preprocessing(train_df)
train_df.head()
# Out:
# sentence0
# sentence1
#                                            sentence0  \
# 0  [but, other, source, close, to, the, sale, sai...
# 1  [micron, ha, declared, it, first, quarterly, p...
# 2  [the, fine, are, part, of, failed, republican,...
# 3  [the, american, anglican, council, which, repr...
# 4  [the, tech, loaded, nasdaq, composite, rose, p...
#
#                                            sentence1
# 0  [but, other, source, close, to, the, sale, sai...
# 1  [micron, s, number, also, marked, the, first, ...
# 2  [perry, said, he, back, the, senate, s, effort...
# 3  [the, american, anglican, council, which, repr...
# 4  [the, technology, laced, nasdaq, composite, in...

# %%
def lexical_simmilarity(df):
    guess = pd.DataFrame()
    for i in df.index:
        guess.loc[i,'labels'] = 1 - jaccard_distance(set(df.loc[i,'sentence0']), set(df.loc[i,'sentence1']))
    return guess

guess_lex = lexical_simmilarity(train_df)
guess_lex.head()
# Out:
#      labels
# 0  0.533333
# 1  0.388889
# 2  0.333333
# 3  0.607143
# 4  0.227273

# %%
print(pearsonr(refs, guess_lex['labels'])[0])
# Out:
# 0.46821213024625113
